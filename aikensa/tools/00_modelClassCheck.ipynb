# %%
from ultralytics import YOLO

# %%
model_path = "../models/P8083X7UA0A_set_correct.pt"
model = YOLO(model_path)
print(model.names)
# Out:
# {0: 'NG', 1: 'OK'}

# %%
model_path = "../models/P8083X7UA0A_detect.pt"
model = YOLO(model_path)
print(model.names)
# Out:
# {0: 'CLIPBROWN', 1: 'CLIPGREEN', 2: 'EPTO'}

# %%
model_path = "../models/P8083X7UA0A_exist.pt"
model = YOLO(model_path)
print(model.names)
# Out:
# {0: 'NG', 1: 'OK'}
